# %%
import requests
from json import loads
import json

url = " https://webexapis.com/v1/rooms?type=group"

headers = {
    'Authorization': 'Bearer NWJmZTNmZjYtYjdhMC00ODJjLTkyYTYtMTAzMjVlMmM2ZWU0N2YwYThkYzUtMDg3_PF84_1eb65fdf-9643-417f-9974-ad72cae0e10f',
    'Content-Type': 'application/json'
}
# Define the data variable, even if not used
data = {}

# Send GET request
response = requests.get(url, headers=headers, data=json.dumps(data))

# Check for HTTP response status
if response.status_code == 200:
    # Parse and pretty print the response JSON
    print(json.dumps(response.json(), sort_keys=True, indent=4))
else:
    # Print error information
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# {
#     "items": [
#         {
#             "created": "2025-01-15T11:41:10.195Z",
#             "creatorId": "Y2lzY29zcGFyazovL3VzL1BFT1BMRS81MjBjMGM3NC0zYzA3LTQ3N2EtODIwMC0wMzA0ODhhMTVkYjA",
#             "id": "Y2lzY29zcGFyazovL3VzL1JPT00vOWQ4ZmQwMzAtZDMzNS0xMWVmLTgwOTItNWZhNzE1ZTQyMjZi",
#             "isLocked": false,
#             "isPublic": false,
#             "isReadOnly": false,
#             "lastActivity": "2025-01-15T12:12:39.955Z",
#             "ownerId": "Y2lzY29zcGFyazovL3VzL09SR0FOSVpBVElPTi8xZWI2NWZkZi05NjQzLTQxN2YtOTk3NC1hZDcyY2FlMGUxMGY",
#             "title": "Kafka-Alerts",
#             "type": "group"
#         },
#         {
#             "created": "2025-01-09T15:29:49.247Z",
#             "creatorId": "Y2lzY29zcGFyazovL3VzL1BFT1BMRS81MjBjMGM3NC0zYzA3LTQ3N2EtODIwMC0wMzA0ODhhMTVkYjA",
#             "id": "Y2lzY29zcGFyazovL3VzL1JPT00vOTA0Njg0ZjAtY2U5ZS0xMWVmLTk4YzgtZjdhMDk5N2E5YTI5",
#             "isLocked": false,
#             "isPublic": false,
# ...
