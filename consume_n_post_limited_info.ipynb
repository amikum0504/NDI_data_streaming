# %%
from kafka import KafkaConsumer, TopicPartition
from json import loads, JSONDecodeError
import requests
import json
import sys

# Kafka Consumer Configuration
KAFKA_BROKER = '10.76.92.36:9092'
KAFKA_TOPIC = 'amikum'
KAFKA_GROUP_ID = 'my-group'

# Webex API Configuration
WEBEX_API_URL = "https://webexapis.com/v1/messages"
WEBEX_ACCESS_TOKEN = 'Bearer NGRlMjdlZjMtMTFjMC00NTgyLWIxYTYtMGM1NzA0ZTQ0NDJkNjhkYzlmOGUtMDU2_PF84_1eb65fdf-9643-417f-9974-ad72cae0e10f'  # Replace with your Webex API token
WEBEX_ROOM_ID = 'Y2lzY29zcGFyazovL3VzL1JPT00vOWQ4ZmQwMzAtZDMzNS0xMWVmLTgwOTItNWZhNzE1ZTQyMjZi'  # Replace with your Webex Room ID

# Webex Headers
headers = {
    'Authorization': WEBEX_ACCESS_TOKEN,
    'Content-Type': 'application/json'
}

# Initialize Kafka Consumer
consumer = KafkaConsumer(
    bootstrap_servers=[KAFKA_BROKER],
    auto_offset_reset='earliest',  # Start reading from the beginning
    enable_auto_commit=True,  # Automatically commit offsets
    group_id=KAFKA_GROUP_ID,
    value_deserializer=lambda x: x.decode('utf-8', errors='ignore') if x else None,
    
)

print("Kafka Consumer initialized. Waiting for messages...")

try:
    # Manually assign partitions
    partitions = consumer.partitions_for_topic(KAFKA_TOPIC)
    if partitions:
        print("Partitions available:", partitions)
        topic_partitions = [TopicPartition(KAFKA_TOPIC, p) for p in partitions]
        consumer.assign(topic_partitions)
        consumer.seek_to_end()  # Start from the end of the topic
    else:
        print("No partitions found for the topic. Exiting...")
        consumer.close()
        sys.exit()

    # Consume messages from Kafka and post to Webex
    for msg in consumer:
        # Check for empty messages
        if not msg.value:
            print("Received an empty message.")
            continue

        try:
            # Attempt to parse the message as JSON
            message = loads(msg.value)
            print(f"Received JSON message from partition {msg.partition}, offset {msg.offset}:")
            print(message)

            # Prepare Webex message payload
            payload_message = (
                f"Fabric={message['fabricName']}, "
                f"Category={message['category']}, "
                f"Type={message['anomalyType']}, "
                f"Object={message['entityName']}, "
                f"Description={message['description']}, "
                f"Node={message['nodeNames']}, "
                f"Cleared={message['cleared']}, "
            )
            payload = {
                "roomId": WEBEX_ROOM_ID,
                "text": payload_message
            }

            # Post message to Webex
            response = requests.post(WEBEX_API_URL, headers=headers, json=payload)

            # Check for success
            if response.status_code == 200:
                print(f"Message posted successfully to Webex: {payload_message}")
            else:
                print(f"Failed to post to Webex. Status: {response.status_code}, Response: {response.text}")

        except JSONDecodeError as e:
            print(f"Failed to parse message from partition {msg.partition}, offset {msg.offset}: {msg.value}. Error: {e}")
        except KeyError as e:
            print(f"Missing key in message: {e}")

except Exception as e:
    print(f"Error while consuming messages: {e}")
finally:
    # Ensure the consumer is closed properly
    consumer.close()
    print("Consumer closed.")
# Out:
# Kafka Consumer initialized. Waiting for messages...
# Partitions available: {0}
# Consumer closed.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 49
#      46     sys.exit()
#      48 # Consume messages from Kafka and post to Webex
# ---> 49 for msg in consumer:
#      50     # Check for empty messages
#      51     if not msg.value:
#      52         print("Received an empty message.")
#
# File /opt/anaconda3/envs/kafka_env/lib/python3.10/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File /opt/anaconda3/envs/kafka_env/lib/python3.10/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File /opt/anaconda3/envs/kafka_env/lib/python3.10/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File /opt/anaconda3/envs/kafka_env/lib/python3.10/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File /opt/anaconda3/envs/kafka_env/lib/python3.10/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File /opt/anaconda3/envs/kafka_env/lib/python3.10/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File /opt/anaconda3/envs/kafka_env/lib/python3.10/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File /opt/anaconda3/envs/kafka_env/lib/python3.10/selectors.py:562, in KqueueSelector.select(self, timeout)
#     560 ready = []
#     561 try:
# --> 562     kev_list = self._selector.control(None, max_ev, timeout)
#     563 except InterruptedError:
#     564     return ready
#
# KeyboardInterrupt:
